# %% [markdown]
# <a href="https://colab.research.google.com/github/curiosity806/2020_dacon_satellite_precipitation/blob/rotation-flip%2Fbaseline/Dacon_satellite_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import random
import sys
import gc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Dropout, MaxPooling2D, BatchNormalization, concatenate, Input
from tensorflow.keras import Model

# %%
# 재생산성을 위해 시드 고정
np.random.seed(7)
random.seed(7)
tf.random.set_seed(7)

# %% [markdown]
# ## 데이터 받아오기

# %%
# import os.path
# if not os.path.isfile('train.npy'):
#     !cp '/content/drive/My Drive/2020 Kaggle Study/data/train.npy' train.npy
# if not os.path.isfile('test.npy'): 
#     !cp '/content/drive/My Drive/2020 Kaggle Study/data/test.npy' test.npy
# if not os.path.isfile('gmi_preci.npy'):
#     !cp '/content/drive/My Drive/2020 Kaggle Study/data/gmi_preci.npy' gmi_preci.npy
train = np.load('/content/drive/My Drive/2020 Kaggle Study/data/train.npy')  # float32
test = np.load('/content/drive/My Drive/2020 Kaggle Study/data/test.npy')  # float64
gmi_preci = np.load('/content/drive/My Drive/2020 Kaggle Study/data/gmi_preci/near2.npy')  # float32
train[:, :, :, -1] = gmi_preci.reshape(-1, 40, 40)

# %% [markdown]
# ## Train test split

# %%
train, val = train_test_split(train, test_size=0.025, random_state=7777)

# %% [markdown]
# ## Data preprocess

# %%
scaler = StandardScaler()
scaler.fit(train[:,:,:,:9].reshape(-1, 9))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
def preprocess(data):
    # Normalize sensor data
    data[:,:,:,:9] = scaler.transform(data[:,:,:,:9].reshape(-1, 9)).reshape(-1, 40, 40, 9)

    # Land type
    land_type_data = data[:,:,:,9]
    data[:,:,:,9] = np.where(land_type_data//100 == 2, 0.7,
                             np.where(land_type_data//100 == 3, 0.3,
                                      land_type_data//100))

    return data

# %%
# -9999를 포함한 이미지, 강수인 지역이 50픽셀 미만인 이미지 제거
is_valid = (train[:,:,:,-1].reshape(-1, 1600) < 0).sum(axis=1) == 0
is_valid = is_valid & ((train[:,:,:,-1].reshape(-1, 1600) >= 0.1).sum(axis=1) >= 50)
train = train[is_valid]  # (-1, 40, 40, 15)

# %%
train = preprocess(train)
val = preprocess(val)

# %% [markdown]
# ## Rotation-flip augmentation

# %%
def r(a, n=1):
    return np.rot90(a, n, (1, 2))

def f_ud(a):
    return np.flip(a, 1)

def f_lr(a):
    return np.flip(a, 2)

def t(a):
    return np.transpose(a, (0, 2, 1, 3))

# %%
abcd = train
acbd = r(f_lr(train))
badc = f_lr(train)
bdac = r(train)
cadb = r(train, 3)
cdab = f_ud(train)
dbca = t(r(train, 2))
dcba = r(train, 2)

# %% [markdown]
# ## 모델만들기

# %%
from sklearn.metrics import f1_score

def mae(y_true, y_pred) :
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    y_true = y_true.reshape(1, -1)[0]
    y_pred = y_pred.reshape(1, -1)[0]
    over_threshold = y_true >= 0.1
    return np.mean(np.abs(y_true[over_threshold] - y_pred[over_threshold]))

def fscore(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    y_true = y_true.reshape(1, -1)[0]
    y_pred = y_pred.reshape(1, -1)[0]
    remove_NAs = y_true >= 0
    y_true = np.where(y_true[remove_NAs] >= 0.1, 1, 0)
    y_pred = np.where(y_pred[remove_NAs] >= 0.1, 1, 0)
    return(f1_score(y_true, y_pred))

def maeOverFscore(y_true, y_pred):
    return mae(y_true, y_pred) / (fscore(y_true, y_pred) + 1e-07)

def fscore_keras(y_true, y_pred):
    score = tf.py_function(func=fscore, inp=[y_true, y_pred], Tout=tf.float32, name='fscore_keras')
    return score

def maeOverFscore_keras(y_true, y_pred):
    score = tf.py_function(func=maeOverFscore, inp=[y_true, y_pred], Tout=tf.float32,  name='custom_mse') 
    return score

# %%
def create_model():
    inputs=Input((40, 40, 10))
    
    bn=BatchNormalization()(inputs)
    conv0=Conv2D(256, kernel_size=1, strides=1, padding='same', activation='relu')(bn)
    
    bn=BatchNormalization()(conv0)
    conv=Conv2D(128, kernel_size=2, strides=1, padding='same', activation='relu')(bn)
    concat=concatenate([conv0, conv], axis=3)
    
    bn=BatchNormalization()(concat)
    conv=Conv2D(64, kernel_size=3, strides=1, padding='same', activation='relu')(bn)
    concat=concatenate([concat, conv], axis=3)

    for i in range(5):
        bn=BatchNormalization()(concat)
        conv=Conv2D(32, kernel_size=3, strides=1, padding='same', activation='relu')(bn)
        concat=concatenate([concat, conv], axis=3)
    
    bn=BatchNormalization()(concat)
    outputs=Conv2D(1, kernel_size=1, strides=1, padding='same', activation='relu')(bn)
    
    model=Model(inputs=inputs, outputs=outputs)
    
    return model

# %% [markdown]
# ## 모델 학습

# %%
x_val, y_val = val[:, :, :, :10], val[:, :, :, -1]
train_data = [[abcd, acbd, badc], [bdac, cadb, cdab], [dbca, dcba, abcd]]

models = []
for t in train_data:
    _train = np.concatenate(t)
    x_train, y_train = _train[:, :, :, :10], _train[:, :, :, -1]

    model = create_model()
    model.compile(loss="mae", optimizer="adam", metrics=[maeOverFscore_keras, fscore_keras])
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_maeOverFscore_keras', patience=4)
    model.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_val, y_val), callbacks=[early_stopping])  # batch_size 128 넘으면 안 됨
    models.append(model)

    del x_train, y_train
    del _train
    gc.collect()
# Out:
# Epoch 1/50
# 755/755 [==============================] - 260s 344ms/step - loss: 0.2332 - maeOverFscore_keras: 1.9762 - fscore_keras: 0.7043 - val_loss: 65.8363 - val_maeOverFscore_keras: 1.6439 - val_fscore_keras: 0.7164
# Epoch 2/50
# 755/755 [==============================] - 259s 343ms/step - loss: 0.2048 - maeOverFscore_keras: 1.6612 - fscore_keras: 0.7483 - val_loss: 65.8442 - val_maeOverFscore_keras: 1.7716 - val_fscore_keras: 0.6352
# Epoch 3/50
# 755/755 [==============================] - 257s 340ms/step - loss: 0.1999 - maeOverFscore_keras: 1.5949 - fscore_keras: 0.7601 - val_loss: 65.8374 - val_maeOverFscore_keras: 1.5730 - val_fscore_keras: 0.7216
# Epoch 4/50
# 755/755 [==============================] - 257s 341ms/step - loss: 0.1979 - maeOverFscore_keras: 1.5679 - fscore_keras: 0.7654 - val_loss: 65.8298 - val_maeOverFscore_keras: 1.5193 - val_fscore_keras: 0.7378
# Epoch 5/50
# 755/755 [==============================] - 257s 340ms/step - loss: 0.1960 - maeOverFscore_keras: 1.5427 - fscore_keras: 0.7704 - val_loss: 65.8363 - val_maeOverFscore_keras: 1.4843 - val_fscore_keras: 0.7195
# Epoch 6/50
# 755/755 [==============================] - 256s 339ms/step - loss: 0.1944 - maeOverFscore_keras: 1.5229 - fscore_keras: 0.7739 - val_loss: 65.8331 - val_maeOverFscore_keras: 1.5157 - val_fscore_keras: 0.7200
# Epoch 7/50
# 755/755 [==============================] - 259s 343ms/step - loss: 0.1934 - maeOverFscore_keras: 1.5119 - fscore_keras: 0.7761 - val_loss: 65.8276 - val_maeOverFscore_keras: 1.3834 - val_fscore_keras: 0.7617
# Epoch 8/50
# 755/755 [==============================] - 256s 340ms/step - loss: 0.1921 - maeOverFscore_keras: 1.4932 - fscore_keras: 0.7796 - val_loss: 65.8334 - val_maeOverFscore_keras: 1.4880 - val_fscore_keras: 0.7374
# Epoch 9/50
# 755/755 [==============================] - 257s 340ms/step - loss: 0.1914 - maeOverFscore_keras: 1.4849 - fscore_keras: 0.7812 - val_loss: 65.8274 - val_maeOverFscore_keras: 1.3942 - val_fscore_keras: 0.7475
# Epoch 10/50
# 755/755 [==============================] - 277s 367ms/step - loss: 0.1903 - maeOverFscore_keras: 1.4707 - fscore_keras: 0.7842 - val_loss: 65.8259 - val_maeOverFscore_keras: 1.3845 - val_fscore_keras: 0.7629
# Epoch 11/50
# 755/755 [==============================] - 276s 365ms/step - loss: 0.1895 - maeOverFscore_keras: 1.4628 - fscore_keras: 0.7861 - val_loss: 65.8269 - val_maeOverFscore_keras: 1.4030 - val_fscore_keras: 0.7472
# Epoch 1/50
# 755/755 [==============================] - 276s 366ms/step - loss: 0.2287 - maeOverFscore_keras: 1.9182 - fscore_keras: 0.7144 - val_loss: 65.8706 - val_maeOverFscore_keras: 2.1370 - val_fscore_keras: 0.5657
# Epoch 2/50
# 755/755 [==============================] - 273s 362ms/step - loss: 0.2051 - maeOverFscore_keras: 1.6665 - fscore_keras: 0.7471 - val_loss: 65.8483 - val_maeOverFscore_keras: 1.7578 - val_fscore_keras: 0.6356
# Epoch 3/50
# 755/755 [==============================] - 263s 348ms/step - loss: 0.1999 - maeOverFscore_keras: 1.5966 - fscore_keras: 0.7594 - val_loss: 65.8376 - val_maeOverFscore_keras: 1.5538 - val_fscore_keras: 0.7155
# Epoch 4/50
# 755/755 [==============================] - 261s 345ms/step - loss: 0.1974 - maeOverFscore_keras: 1.5649 - fscore_keras: 0.7653 - val_loss: 65.8310 - val_maeOverFscore_keras: 1.4825 - val_fscore_keras: 0.7463
# Epoch 5/50
# 755/755 [==============================] - 260s 345ms/step - loss: 0.1957 - maeOverFscore_keras: 1.5407 - fscore_keras: 0.7704 - val_loss: 65.8423 - val_maeOverFscore_keras: 1.5852 - val_fscore_keras: 0.6897
# Epoch 6/50
# 755/755 [==============================] - 268s 355ms/step - loss: 0.1944 - maeOverFscore_keras: 1.5250 - fscore_keras: 0.7728 - val_loss: 65.8308 - val_maeOverFscore_keras: 1.5783 - val_fscore_keras: 0.7113
# Epoch 7/50
# 755/755 [==============================] - 265s 351ms/step - loss: 0.1931 - maeOverFscore_keras: 1.5098 - fscore_keras: 0.7764 - val_loss: 65.8271 - val_maeOverFscore_keras: 1.4122 - val_fscore_keras: 0.7531
# Epoch 8/50
# 755/755 [==============================] - 262s 347ms/step - loss: 0.1920 - maeOverFscore_keras: 1.4941 - fscore_keras: 0.7792 - val_loss: 65.8301 - val_maeOverFscore_keras: 1.5261 - val_fscore_keras: 0.7298
# Epoch 9/50
# 755/755 [==============================] - 260s 344ms/step - loss: 0.1917 - maeOverFscore_keras: 1.4890 - fscore_keras: 0.7804 - val_loss: 65.8275 - val_maeOverFscore_keras: 1.4280 - val_fscore_keras: 0.7484
# Epoch 10/50
# 755/755 [==============================] - 256s 339ms/step - loss: 0.1906 - maeOverFscore_keras: 1.4764 - fscore_keras: 0.7829 - val_loss: 65.8263 - val_maeOverFscore_keras: 1.3981 - val_fscore_keras: 0.7611
# Epoch 11/50
# 755/755 [==============================] - 256s 339ms/step - loss: 0.1900 - maeOverFscore_keras: 1.4702 - fscore_keras: 0.7845 - val_loss: 65.8308 - val_maeOverFscore_keras: 1.4716 - val_fscore_keras: 0.7268
# Epoch 12/50
# 755/755 [==============================] - 257s 340ms/step - loss: 0.1892 - maeOverFscore_keras: 1.4607 - fscore_keras: 0.7860 - val_loss: 65.8323 - val_maeOverFscore_keras: 1.4817 - val_fscore_keras: 0.7087
# Epoch 13/50
# 755/755 [==============================] - 255s 338ms/step - loss: 0.1885 - maeOverFscore_keras: 1.4487 - fscore_keras: 0.7890 - val_loss: 65.8277 - val_maeOverFscore_keras: 1.4876 - val_fscore_keras: 0.7338
# Epoch 14/50
# 755/755 [==============================] - 255s 338ms/step - loss: 0.1878 - maeOverFscore_keras: 1.4421 - fscore_keras: 0.7898 - val_loss: 65.8275 - val_maeOverFscore_keras: 1.4284 - val_fscore_keras: 0.7486
# Epoch 1/50
# 755/755 [==============================] - 258s 342ms/step - loss: 0.2308 - maeOverFscore_keras: 1.9708 - fscore_keras: 0.7052 - val_loss: 65.8383 - val_maeOverFscore_keras: 1.7120 - val_fscore_keras: 0.6971
# Epoch 2/50
# 755/755 [==============================] - 258s 341ms/step - loss: 0.2050 - maeOverFscore_keras: 1.6606 - fscore_keras: 0.7493 - val_loss: 65.8380 - val_maeOverFscore_keras: 1.6215 - val_fscore_keras: 0.6883
# Epoch 3/50
# 755/755 [==============================] - 255s 338ms/step - loss: 0.1995 - maeOverFscore_keras: 1.5894 - fscore_keras: 0.7614 - val_loss: 65.8307 - val_maeOverFscore_keras: 1.4713 - val_fscore_keras: 0.7489
# Epoch 4/50
# 755/755 [==============================] - 256s 339ms/step - loss: 0.1971 - maeOverFscore_keras: 1.5582 - fscore_keras: 0.7673 - val_loss: 65.8294 - val_maeOverFscore_keras: 1.4974 - val_fscore_keras: 0.7445
# Epoch 5/50
# 755/755 [==============================] - 253s 336ms/step - loss: 0.1954 - maeOverFscore_keras: 1.5362 - fscore_keras: 0.7715 - val_loss: 65.8342 - val_maeOverFscore_keras: 1.5296 - val_fscore_keras: 0.7072
# Epoch 6/50
# 755/755 [==============================] - 255s 337ms/step - loss: 0.1940 - maeOverFscore_keras: 1.5180 - fscore_keras: 0.7747 - val_loss: 65.8309 - val_maeOverFscore_keras: 1.5744 - val_fscore_keras: 0.7082
# Epoch 7/50
# 755/755 [==============================] - 253s 335ms/step - loss: 0.1926 - maeOverFscore_keras: 1.5008 - fscore_keras: 0.7787 - val_loss: 65.8286 - val_maeOverFscore_keras: 1.4037 - val_fscore_keras: 0.7489
# Epoch 8/50
# 755/755 [==============================] - 257s 341ms/step - loss: 0.1917 - maeOverFscore_keras: 1.4890 - fscore_keras: 0.7804 - val_loss: 65.8310 - val_maeOverFscore_keras: 1.5040 - val_fscore_keras: 0.7284
# Epoch 9/50
# 755/755 [==============================] - 256s 339ms/step - loss: 0.1913 - maeOverFscore_keras: 1.4839 - fscore_keras: 0.7817 - val_loss: 65.8264 - val_maeOverFscore_keras: 1.3757 - val_fscore_keras: 0.7666
# Epoch 10/50
# 755/755 [==============================] - 257s 341ms/step - loss: 0.1899 - maeOverFscore_keras: 1.4654 - fscore_keras: 0.7857 - val_loss: 65.8261 - val_maeOverFscore_keras: 1.4115 - val_fscore_keras: 0.7535
# Epoch 11/50
# 755/755 [==============================] - 259s 343ms/step - loss: 0.1895 - maeOverFscore_keras: 1.4613 - fscore_keras: 0.7868 - val_loss: 65.8270 - val_maeOverFscore_keras: 1.4041 - val_fscore_keras: 0.7465
# Epoch 12/50
# 755/755 [==============================] - 258s 341ms/step - loss: 0.1887 - maeOverFscore_keras: 1.4526 - fscore_keras: 0.7881 - val_loss: 65.8271 - val_maeOverFscore_keras: 1.3617 - val_fscore_keras: 0.7644
# Epoch 13/50
# 755/755 [==============================] - 256s 340ms/step - loss: 0.1879 - maeOverFscore_keras: 1.4397 - fscore_keras: 0.7912 - val_loss: 65.8272 - val_maeOverFscore_keras: 1.4253 - val_fscore_keras: 0.7568
# Epoch 14/50
# 755/755 [==============================] - 256s 339ms/step - loss: 0.1872 - maeOverFscore_keras: 1.4337 - fscore_keras: 0.7921 - val_loss: 65.8244 - val_maeOverFscore_keras: 1.3448 - val_fscore_keras: 0.7713
# Epoch 15/50
# 755/755 [==============================] - 258s 341ms/step - loss: 0.1868 - maeOverFscore_keras: 1.4278 - fscore_keras: 0.7927 - val_loss: 65.8268 - val_maeOverFscore_keras: 1.4051 - val_fscore_keras: 0.7532
# Epoch 16/50
# 755/755 [==============================] - 257s 341ms/step - loss: 0.1862 - maeOverFscore_keras: 1.4204 - fscore_keras: 0.7944 - val_loss: 65.8246 - val_maeOverFscore_keras: 1.3611 - val_fscore_keras: 0.7649
# Epoch 17/50
# 755/755 [==============================] - 257s 341ms/step - loss: 0.1855 - maeOverFscore_keras: 1.4112 - fscore_keras: 0.7960 - val_loss: 65.8266 - val_maeOverFscore_keras: 1.3880 - val_fscore_keras: 0.7631
# Epoch 18/50
# 755/755 [==============================] - 257s 341ms/step - loss: 0.1851 - maeOverFscore_keras: 1.4081 - fscore_keras: 0.7966 - val_loss: 65.8241 - val_maeOverFscore_keras: 1.3377 - val_fscore_keras: 0.7726
# Epoch 19/50
# 755/755 [==============================] - 258s 341ms/step - loss: 0.1847 - maeOverFscore_keras: 1.4044 - fscore_keras: 0.7974 - val_loss: 65.8246 - val_maeOverFscore_keras: 1.3913 - val_fscore_keras: 0.7532
# Epoch 20/50
# 755/755 [==============================] - 257s 340ms/step - loss: 0.1841 - maeOverFscore_keras: 1.3964 - fscore_keras: 0.7986 - val_loss: 65.8232 - val_maeOverFscore_keras: 1.3206 - val_fscore_keras: 0.7790
# Epoch 21/50
# 755/755 [==============================] - 257s 340ms/step - loss: 0.1835 - maeOverFscore_keras: 1.3909 - fscore_keras: 0.7994 - val_loss: 65.8229 - val_maeOverFscore_keras: 1.3068 - val_fscore_keras: 0.7776
# Epoch 22/50
# 755/755 [==============================] - 257s 340ms/step - loss: 0.1831 - maeOverFscore_keras: 1.3847 - fscore_keras: 0.8007 - val_loss: 65.8260 - val_maeOverFscore_keras: 1.4098 - val_fscore_keras: 0.7528
# Epoch 23/50
# 755/755 [==============================] - 256s 339ms/step - loss: 0.1827 - maeOverFscore_keras: 1.3834 - fscore_keras: 0.8009 - val_loss: 65.8244 - val_maeOverFscore_keras: 1.3897 - val_fscore_keras: 0.7576
# Epoch 24/50
# 755/755 [==============================] - 256s 340ms/step - loss: 0.1823 - maeOverFscore_keras: 1.3775 - fscore_keras: 0.8017 - val_loss: 65.8227 - val_maeOverFscore_keras: 1.3251 - val_fscore_keras: 0.7772
# Epoch 25/50
# 755/755 [==============================] - 257s 340ms/step - loss: 0.1819 - maeOverFscore_keras: 1.3739 - fscore_keras: 0.8023 - val_loss: 65.8252 - val_maeOverFscore_keras: 1.3391 - val_fscore_keras: 0.7666

# %%
## 모델 저장하기
cnt = 0
for model in models:
    cnt += 1
    model.save(f'/content/drive/My Drive/2020 Kaggle Study/model/model{cnt}.h5')

# %% [markdown]
# ## Precipatation GMI -> DPR

# %%
dr = [(-1, -1), (-1, 0), (-1, 1),
      (0, -1), (0, 0), (0, 1),
      (1, -1), (1, 0), (1, 1)]

def get_dist(p1, p2):  # p1, p2: shape=(-1, 2).
    x1, y1 = np.deg2rad(p1[:,0]), np.deg2rad(p1[:,1])
    x2, y2 = np.deg2rad(p2[:,0]), np.deg2rad(p2[:,1])
    dlon = x2 - x1
    dlat = y2 - y1
    a = np.sin(dlat/2)**2 + np.cos(y1) * np.cos(y2) * np.sin(dlon/2)**2 
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))    
    return 6373.0 * c  # km, shape=(-1).

# value: (40, 40, -1)
# ori_ll, tgt_ll: (40, 40, 2)
def compen_ll(value, ori_ll, tgt_ll):  # ori_ll에서의 value를 tgt_ll에 대한 값으로 바꿈
    ret = np.empty_like(value)
    n, m = value.shape[0], value.shape[1]
    for i in range(n):
        for j in range(m):
            nears = []  # (row, col, value)
            for k in range(9):
                ii = i + dr[k][0]
                jj = j + dr[k][1]
                if ii >= 0 and ii < n and jj >= 0 and jj < m:
                    nears.append((ori_ll[ii, jj][0], ori_ll[ii, jj][1],
                                  tgt_ll[i, j][0], tgt_ll[i, j][1],
                                  value[ii, jj]))
            nears = np.array(nears)  # shape=(-1, 5)
            dists = get_dist(nears[:, 0:2], nears[:, 2:4]).reshape(-1, 1)
            values = nears[:, 4].reshape(-1, 1)
            nears = np.concatenate((dists, values), 1)
            nears = nears[np.argsort(nears[:, 0])]  # sort by dist
            nears = nears[:2, :]  # 가까운 점 2개만 고려
            
            weights = 1 / (nears[:, 0] ** 2 + sys.float_info.epsilon)
            weighted_sum = (weights * nears[:, 1]).sum()
            ret[i, j] = weighted_sum / weights.sum()
    return ret

# %%
from multiprocessing import Process, Manager

def proc_func(splitted, dpr_preci, proc_id):
    part = splitted[proc_id]
    arr = np.empty_like(part[:, :, :, 14])  # shape=(-1, 40, 40)
    for i in range(part.shape[0]):
        arr[i, :, :] = compen_ll(part[i, :, :, 14], part[i, :, :, 10:12], part[i, :, :, 12:14])
    dpr_preci[proc_id] = arr

def gmi2dpr(test, gmi_preci):
    n_procs = 4
    procs = []
    manager = Manager()
    dpr_preci = manager.list([None] * n_procs)

    data = np.concatenate((test, gmi_preci), axis=3)
    n_imgs = data.shape[0]  # split data into n_procs arrays
    splitted = np.split(data, np.arange(n_imgs // n_procs + n_imgs % n_procs, n_imgs, n_imgs // n_procs))

    for proc_id in range(n_procs):
        proc = Process(target=proc_func, args=(splitted, dpr_preci, proc_id))
        proc.start()
        procs.append(proc)

    for proc in procs:
        proc.join()

    dpr_preci = np.concatenate(dpr_preci)
    return dpr_preci

# %%
test = preprocess(test)
x_test = test[:, :, :, :10]

preds = []
for model in models:
    pred = model.predict(x_test)
    pred = gmi2dpr(test, pred)
    preds.append(pred)
final_pred = sum(preds) / len(preds)

# %% [markdown]
# ## submission 만들기

# %%
submission = pd.read_csv('/content/drive/My Drive/2020 Kaggle Study/data/sample_submission.csv')
submission.iloc[:,1:] = final_pred.reshape(-1, 1600)

# %%
# 제출 파일 저장하기
submission.to_csv('/content/drive/My Drive/2020 Kaggle Study/submission/submission2010.csv', index=False)
submission
# Out:
#              id      px_1      px_2  ...   px_1598   px_1599   px_1600
# 0     029858_01  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1     029858_02  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2     029858_03  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 3     029858_05  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 4     029858_07  0.000000  0.000000  ...  3.415471  2.424429  1.676327
# ...         ...       ...       ...  ...       ...       ...       ...
# 2411  031287_08  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2412  031288_01  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2413  031288_02  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2414  031288_08  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2415  031288_11  0.526725  0.525549  ...  0.000000  0.000000  0.000000
#
# [2416 rows x 1601 columns]
